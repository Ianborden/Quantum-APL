# %%
h = 6.626 * 10^-34
hbar = h/(π)

ω01 = 0
ω12 = 0
Δ = ω12 - 2 * ω01
ωd = 0

λ1 = 1
#λ2 = λ

Ex = 0
Ey = 0

tg = 50
function Epsilon(t)
    Ex(t)* cos(ωd * t) + Ey(t) * sin(ωd * t)
end

δ1 = ω01 - ωd
δ2 = Δ + 2δ1

zero_state = basis(3, 0)
one_state = basis(3, 1)
two_state = basis(3, 2)

function PI(x)
    return x * x'
end

function Indexone(t)
    return ω01 * PI(one_state) + Epsilon(t) * λ1 * () 
end

function Indextwo(t)
    ω12 * PI(two_state)
end
#H = hbar * ()
# Out:
# UndefVarError: `basis` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/ASPIREProjects/Projects/Week 4/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W0sZmlsZQ==.jl:23
