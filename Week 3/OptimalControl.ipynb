# %%
using Optim
using LinearAlgebra
using DifferentialEquations

# %%
N = 20 # number of timesteps
Δt = 0.5 # s
initial = [1.0; 0.0]
u0 = randn(1, N)

struct QuantumSystem{M, V}
    H_drift::M
    H_drives::V
end

function schrodinger!(dψ, ψ, p, t)
    
    dψ .= -0.5* im * p.H_drives * ψ

    return dψ

function objective(controls)

# 1. Integrate
# 2. Return infidelity
end

#minimize with respect to u the cost function


#Single shoot method where we go to a random spot and see how we did and then recalculate to improve


# calculate which time slice we are currently in
# consider using mul!
end
# Out:
# schrodinger! (generic function with 1 method)
